# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from os.path import basename, dirname
from shutil import copyfile

import json
import pickle
from collections import OrderedDict

import torch

# %%
from sklearn.cluster import KMeans
import pandas as pd
import seaborn as sns

# %%
import numpy as np

# %%
os.chdir("..")

# %%
from da.clust_utils import cramers_corrected_stat, flatten_dict, kmeans_train, kmeans_predict

# %%
np.random.seed(21)

# %%
model_name  = 'concat60'

# %% [markdown]
# # NMT sent clusters

# %%
import matplotlib.pyplot as plt

with open(f"experiments/en_et_{model_name}/internals-docs/kmeans_train_sent.pkl", 'rb') as f:
    kmeans = pickle.load(f)
    
savedir = f"experiments/en_et_{model_name}/nmt-clusters-sent"
if not os.path.isdir(savedir):
    os.mkdir(savedir)

for split in ['train', 'dev-cl', 'test-cl']:
    fn = f"experiments/en_et_{model_name}/internals-docs/sent_means_{split}.pkl"
    with open(fn, 'rb') as f:
        data_encoded = pickle.load(f)
    
    labels_hat, labels_true = kmeans_predict(kmeans, data_encoded, split=='train')
    
    conf_matrix = pd.crosstab(labels_true, labels_hat)
    corr_k = cramers_corrected_stat(conf_matrix)

    print(f"Corr k: {corr_k}")
    print(conf_matrix)
    
    i = 0
    for domain_name, v in data_encoded.items():
        fn = f"{domain_name}.{split}.clust.nmt.sent"
        np.savetxt(f"{savedir}/{fn}", labels_hat[i:i+len(v)].astype(int), fmt="%i")
        i += len(v)

    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)
    plt.show()
# Out:
# Corr k: 0.694819275946228
# col_0              0       1       2       3
# row_0
# EMEA           87476    4999    5172  312893
# Europarl        6680  446613   44640    2233
# JRC-Acquis     98987  370022    5045   25966
# OpenSubtitles  59505   13907  426244    1220
# Corr k: 0.741079470183595
# col_0            0     1     2     3
# row_0
# EMEA           304    53    48  2943
# Europarl         5  3470   235     6
# JRC-Acquis     151  2715    38   101
# OpenSubtitles  151    91  2798     4
# Corr k: 0.7339679418290467
# col_0            0     1     2     3
# row_0
# EMEA           262    69    30  2954
# Europarl        10  2810   264    23
# JRC-Acquis      89  2940    29   132
# OpenSubtitles  126   132  2821     6

# %% [markdown]
# # NMT doc clusters

# %%
import matplotlib.pyplot as plt

with open(f"experiments/en_et_{model_name}/internals-docs/kmeans_train_doc.pkl", 'rb') as f:
    kmeans = pickle.load(f)
    
savedir = f"experiments/en_et_{model_name}/nmt-clusters-sent"
if not os.path.isdir(savedir):
    os.mkdir(savedir)

for split in ['train', 'dev-cl', 'test-cl']:
    fn = f"experiments/en_et_{model_name}/internals-docs/sent_means_{split}.pkl"
    with open(fn, 'rb') as f:
        data_encoded = pickle.load(f)
    
    labels_hat, labels_true = kmeans_predict(kmeans, data_encoded, split=='train')
    
    conf_matrix = pd.crosstab(labels_true, labels_hat)
    corr_k = cramers_corrected_stat(conf_matrix)

    print(f"Corr k: {corr_k}")
    print(conf_matrix)
    
    i = 0
    for domain_name, v in data_encoded.items():
        fn = f"{domain_name}.{split}.clust.nmt.sent"
        np.savetxt(f"{savedir}/{fn}", labels_hat[i:i+len(v)].astype(int), fmt="%i")
        i += len(v)

    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)
    plt.show()
# Out:
# Corr k: 0.9949626561782315
# col_0               0       1       2       3
# row_0
# EMEA                0     162  410365      13
# Europarl          118  499635       7     406
# JRC-Acquis          0    6019     484  493517
# OpenSubtitles  500540     336       0       0
# Corr k: 0.8917470817592663
# col_0             0     1     2     3
# row_0
# EMEA             54   142  3102    50
# Europarl        115  3573     1    27
# JRC-Acquis       26   438    54  2487
# OpenSubtitles  2820   219     4     1
# Corr k: 0.8836198579814191
# col_0             0     1     2     3
# row_0
# EMEA             32    92  3127    64
# Europarl        121  2933    12    41
# JRC-Acquis       19   460    46  2665
# OpenSubtitles  2796   268    16     5

# %% [markdown]
# # Bert layer 11 sent clusters

# %%
model_name = 'xlm-roberta-base'

# %%
import matplotlib.pyplot as plt

with open(f"experiments/en_et_{model_name}/internals-docs/kmeans_train_sent.pkl", 'rb') as f:
    kmeans = pickle.load(f)
    
savedir = f"experiments/en_et_{model_name}/nmt-clusters-sent"
if not os.path.isdir(savedir):
    os.mkdir(savedir)

for split in ['train', 'dev-cl', 'test-cl']:
    fn = f"experiments/en_et_{model_name}/internals-docs/sent_means_{split}.pkl"
    with open(fn, 'rb') as f:
        data_encoded = pickle.load(f)
    
    labels_hat, labels_true = kmeans_predict(kmeans, data_encoded, split=='train')
    
    conf_matrix = pd.crosstab(labels_true, labels_hat)
    corr_k = cramers_corrected_stat(conf_matrix)

    print(f"Corr k: {corr_k}")
    print(conf_matrix)
    
    i = 0
    for domain_name, v in data_encoded.items():
        fn = f"{domain_name}.{split}.clust.nmt.sent"
        np.savetxt(f"{savedir}/{fn}", labels_hat[i:i+len(v)].astype(int), fmt="%i")
        i += len(v)

    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)
    plt.show()
# Out:
# Corr k: 0.36107611320457045
# col_0               0      1       2       3
# row_0
# EMEA           164064  28303  123955   94218
# Europarl       135936    879  336682   26669
# JRC-Acquis     117046  70862  278139   33973
# OpenSubtitles  184534  45496    8221  262625
# Corr k: 0.36929188429688964
# col_0             0    1     2     3
# row_0
# EMEA           1431  106  1350   461
# Europarl        939    2  2656   119
# JRC-Acquis      621   43  2151   190
# OpenSubtitles  1330   81    57  1576
# Corr k: 0.3716364232821842
# col_0             0   1     2     3
# row_0
# EMEA           1423  96  1457   339
# Europarl        888   1  2096   122
# JRC-Acquis      604  25  2431   130
# OpenSubtitles  1412  80    91  1502

# %% [markdown]
# # BERT layer 11 doc clusters

# %%
import matplotlib.pyplot as plt

with open(f"experiments/en_et_{model_name}/internals-docs/kmeans_train_doc.pkl", 'rb') as f:
    kmeans = pickle.load(f)
    
savedir = f"experiments/en_et_{model_name}/nmt-clusters-sent"
if not os.path.isdir(savedir):
    os.mkdir(savedir)

for split in ['train', 'dev-cl', 'test-cl']:
    fn = f"experiments/en_et_{model_name}/internals-docs/sent_means_{split}.pkl"
    with open(fn, 'rb') as f:
        data_encoded = pickle.load(f)
    
    labels_hat, labels_true = kmeans_predict(kmeans, data_encoded, split=='train')
    
    conf_matrix = pd.crosstab(labels_true, labels_hat)
    corr_k = cramers_corrected_stat(conf_matrix)

    print(f"Corr k: {corr_k}")
    print(conf_matrix)
    
    i = 0
    for domain_name, v in data_encoded.items():
        fn = f"{domain_name}.{split}.clust.nmt.sent"
        np.savetxt(f"{savedir}/{fn}", labels_hat[i:i+len(v)].astype(int), fmt="%i")
        i += len(v)

    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)
    plt.show()
# Out:
# Corr k: 0.9455906572989493
# col_0               0       1       2       3
# row_0
# EMEA             9514      96     526  400404
# Europarl          242    3051  495773    1100
# JRC-Acquis       6765  436396   41681   15178
# OpenSubtitles  498222       0     336    2318
# Corr k: 0.5029391916992079
# col_0             0    1     2     3
# row_0
# EMEA            466   31  1450  1401
# Europarl        167  117  3224   208
# JRC-Acquis      205  518  2110   172
# OpenSubtitles  2424    3   371   246
# Corr k: 0.48098174138264654
# col_0             0    1     2     3
# row_0
# EMEA            390   50  1597  1278
# Europarl        158  105  2624   220
# JRC-Acquis      148  496  2370   176
# OpenSubtitles  2353    3   458   271

# %% [markdown]
# # Bert layer 7 sent clusters

# %%
labels_bert = {}
domain_names = ["Europarl", "OpenSubtitles", "JRC-Acquis", "EMEA"]
for split in ['train', 'dev-cl', 'test-cl']:

    for domain_name in domain_names:
        fn = f"experiments/data-clust/clusters/cl-{domain_name}.en-et.docs.{split}.clusters_sent_4.txt" # TODO: change to train
        with open(fn) as f:
            labels_bert[domain_name] = [int(l[:-1]) for l in f.readlines()]


    labels_bert_all = []
    labels_bert_all_true = []
    for k,v in labels_bert.items():
        labels_bert_all.extend(v)
        labels_bert_all_true.extend([k] * len(v))



    conf_matrix = pd.crosstab(np.array(labels_bert_all_true), np.array(labels_bert_all))
    corr_k = cramers_corrected_stat(conf_matrix)
    print(corr_k)
    print(conf_matrix)

    print()
    print(conf_matrix.sum(axis=0))
    
    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)

    plt.show()
# Out:
# 0.24168047830449288
# col_0               0       1      2       3
# row_0
# EMEA            72707  140991  39598  157244
# Europarl       166334  177192  56586  100054
# JRC-Acquis     162534  163134  29920  144432
# OpenSubtitles   46245   50394  84391  319846
#
# col_0
# 0    447820
# 1    531711
# 2    210495
# 3    721576
# dtype: int64
# 0.2548759115018526
# col_0             0     1    2     3
# row_0
# EMEA            777  1258  188  1125
# Europarl       1342  1277  371   726
# JRC-Acquis     1279   689  185   852
# OpenSubtitles   194   398  534  1918
#
# col_0
# 0    3592
# 1    3622
# 2    1278
# 3    4621
# dtype: int64
# 0.24212417442137057
# col_0             0     1    2     3
# row_0
# EMEA            891  1134  179  1111
# Europarl        967  1209  341   590
# JRC-Acquis     1452   730  199   809
# OpenSubtitles   351   393  447  1894
#
# col_0
# 0    3661
# 1    3466
# 2    1166
# 3    4404
# dtype: int64

# %% [markdown]
# # Bert 7 doc clusters

# %%
labels_bert = {}
domain_names = ["Europarl", "OpenSubtitles", "JRC-Acquis", "EMEA"]

for split in ['train', 'dev-cl', 'test-cl']:

    for domain_name in domain_names:
        fn = f"experiments/data-clust/clusters/cl-{domain_name}.en-et.docs.{split}.clusters_doc_4.txt" # TODO: change to train
        with open(fn) as f:
            labels_bert[domain_name] = [int(l[:-1]) for l in f.readlines()]


    labels_bert_all = []
    labels_bert_all_true = []
    for k,v in labels_bert.items():
        labels_bert_all.extend(v)
        labels_bert_all_true.extend([k] * len(v))



    conf_matrix = pd.crosstab(np.array(labels_bert_all_true), np.array(labels_bert_all))
    corr_k = cramers_corrected_stat(conf_matrix)
    print(corr_k)
    print(conf_matrix)


    sns.heatmap(conf_matrix,
                cmap="YlGnBu", annot=True, cbar=False)
    
    print()
    #print(conf_matrix.sum(axis=0))
    
    plt.show()
# Out:
# 0.8089680719230101
# col_0               0       1       2       3
# row_0
# EMEA            42870  344373    3200   20097
# Europarl          521    3372  493821    2452
# JRC-Acquis     279334  152902   61959    5825
# OpenSubtitles    1001    9881     899  489095
# 0.7643559453123278
# col_0             0     1     2     3
# row_0
# EMEA           1616  1592   120    20
# Europarl          0     0  3716     0
# JRC-Acquis     1506   168  1326     5
# OpenSubtitles     0     0     0  3044
# 0.780887189413313
# col_0            0     1     2     3
# row_0
# EMEA           683  2532    46    54
# Europarl        11     9  3066    21
# JRC-Acquis     924    58  2208     0
# OpenSubtitles    0     0     0  3085

# %% [markdown]
# # Rand clusters

# %%
from random import sample

labels_rand = {}
domain_names = ["Europarl", "OpenSubtitles", "JRC-Acquis", "EMEA"]
for domain_name in domain_names:
    fn = f"experiments/data-clust-new/clusters/cl-{domain_name}.en-et.docs.train.clusters_doc_4.txt" # TODO: change to train
    with open(fn) as f:
        labels_rand[domain_name] = [sample([0,1,2,3], 1)[0] for l in f.readlines()]
        
        
labels_rand_all = []
labels_rand_all_true = []
for k,v in labels_rand.items():
    labels_rand_all.extend(v)
    labels_rand_all_true.extend([k] * len(v))
    
    
conf_matrix = pd.crosstab(np.array(labels_rand_all_true), np.array(labels_rand_all))
corr_k = cramers_corrected_stat(conf_matrix)
print(corr_k)
print(conf_matrix)


sns.heatmap(conf_matrix,
            cmap="YlGnBu", annot=True, cbar=False)

plt.show()
# Out:
# 0.0
# col_0               0       1       2       3
# row_0
# EMEA           102629  103184  102148  102579
# Europarl       124871  125306  125292  124697
# JRC-Acquis     125152  125205  124859  124804
# OpenSubtitles  125292  124911  125181  125492
